# %%
from ccs import get_closed_contour, get_test_image
import matplotlib.pyplot as plt
# %matplotlib inline

# get test image
testimg = get_test_image()

# segment image
px,py,mask = get_closed_contour(testimg)

# plot results
plt.figure(figsize=(10,10))
plt.subplot(131)
plt.imshow(testimg,interpolation='none',cmap='gray')
plt.xlabel('image')
plt.subplot(132)
plt.imshow(testimg,interpolation='none',cmap='gray')
plt.xlabel('segmented contour \n overlaid on image')
plt.plot(px,py,color='red')
plt.subplot(133)
plt.imshow(mask,interpolation='none',cmap='gray')
plt.xlabel('generated mask \n based on contour')
# Out:
# Text(0.5,0,'generated mask \n based on contour')

# %% [markdown]
# Reference
#
# Chiu SJ, Toth CA, Rickman CB, Izatt JA, Farsiu S. Automatic segmentation of closed-contour features in ophthalmic images using graph theory and dynamic programming. Biomedical optics express. 2012 May 1;3(5):1127-40.
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3342188/?report=classic
